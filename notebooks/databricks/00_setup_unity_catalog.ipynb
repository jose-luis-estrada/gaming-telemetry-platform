# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.telemetry;
CREATE VOLUME IF NOT EXISTS workspace.telemetry.landing;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.telemetry.checkpoints;

# %%
# %sql
DROP TABLE IF EXISTS workspace.telemetry.bronze_player_events;

# %%
dbutils.fs.rm("/Volumes/workspace/telemetry/checkpoints/player_events", recurse=True)
